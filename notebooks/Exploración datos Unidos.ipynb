# %%
import pandas as pd

# %%
df  = pd.read_csv('../data/estudiantes_unidos.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 99 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   TIPO_DOCUMENTO                      766 non-null    object
#  1   DOCUMENTO                           766 non-null    int64
#  2   GENERO                              766 non-null    object
#  3   NOMBRE                              766 non-null    object
#  4   UNIDAD_x                            766 non-null    object
#  5   PENSUM_x                            766 non-null    object
#  6   FECHA_ACTUALIZACION                 433 non-null    object
#  7   ESTADO SOCIODEMOGRAFICO             433 non-null    object
#  8   ESTADO VULNERABILIDAD               433 non-null    object
#  9   ESTADO CONDICIONES DE SALUD         433 non-null    object
#  10  UBICACION_SEMESTRAL                 766 non-null    int64
# ...
