# %%
import pandas as pd

# %%
df  = pd.read_csv('../data/desempeño_areas_formacion.csv')

# %%
df.head()
# Out:
#   PERIODO                FACULTAD                            UNIDAD  \
# 0  2019-1  FACULTAD DE INGENIERÍA  UNIDAD REGIONAL, SEDE FUSAGASUGÁ
# 1  2019-1  FACULTAD DE INGENIERÍA  UNIDAD REGIONAL, SEDE FUSAGASUGÁ
# 2  2019-1  FACULTAD DE INGENIERÍA  UNIDAD REGIONAL, SEDE FUSAGASUGÁ
# 3  2019-1  FACULTAD DE INGENIERÍA  UNIDAD REGIONAL, SEDE FUSAGASUGÁ
# 4  2019-1  FACULTAD DE INGENIERÍA  UNIDAD REGIONAL, SEDE FUSAGASUGÁ
#
#                                               PENSUM   DOCUMENTO  \
# 0  INGENIERIA DE SISTEMAS Y COMPUTACION 2020 FUSA...  1000136072
# 1  INGENIERIA DE SISTEMAS Y COMPUTACION 2020 FUSA...  1000320087
# 2  INGENIERIA DE SISTEMAS Y COMPUTACION 2020 FUSA...  1000592838
# 3  INGENIERIA DE SISTEMAS Y COMPUTACION 2020 FUSA...  1001346777
# 4  INGENIERIA DE SISTEMAS Y COMPUTACION 2020 FUSA...  1003515700
#
#                            NOMBRES MATRICULA_ACTUAL  \
# 0     FORERO HERRERA TANIA NICKOLL    SIN MATRICULA
# 1        MESA BLANCO LEONARDO JUAN    SIN MATRICULA
# ...

# %%
df_2 = pd.read_csv("udec_desercion_isc_caracterizacion.csv")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)     # autodetecta ancho
display(df_2.head(20))
# Out:
#      DOCUMENTO GENERO  UBICACION_SEMESTRAL     MEDIO_TRANSPORTE  \
# 0   1069737604      M                    2            Bicicleta
# 1   1026290752      M                    9  Vehículo motorizado
# 2   1069750774      M                    9                A pie
# 3   1069747785      M                    5                A pie
# 4   1069760977      M                    9                A pie
# 5   1069744582      M                    8     Servicio público
# 6   1069755791      M                    3     Servicio público
# 7   1032460863      M                    8            Bicicleta
# 8   1069749942      M                    0     Servicio público
# 9   1015451974      M                    9     Servicio público
# 10  1069758182      M                    9                A pie
# 11  1030622115      M                    9                A pie
# 12  1069762616      M                    9                A pie
# 13  1069762376      M                    9                A pie
# ...

# %%
df_2
# Out:
#       DOCUMENTO GENERO  UBICACION_SEMESTRAL     MEDIO_TRANSPORTE  \
# 0    1069737604      M                    2            Bicicleta
# 1    1026290752      M                    9  Vehículo motorizado
# 2    1069750774      M                    9                A pie
# 3    1069747785      M                    5                A pie
# 4    1069760977      M                    9                A pie
# ..          ...    ...                  ...                  ...
# 825    11202693      M                    6     Servicio público
# 826  1023970909      M                    0     Servicio público
# 827  1007664640      M                    2     Servicio público
# 828  1000693735      F                    0     Servicio público
# 829  1069716513      M                    2     Servicio público
#
#     FRECUENCIA_TRANSPORTE FUENTES_FINANCIACION PERSONAS_A_CARGO  \
# 0                    Otro     Recursos propios       CON_CARGAS
# ...

# %%
import os, pandas as pd
print("cwd:", os.getcwd())
print("existe archivo:", os.path.exists("udec_desercion_isc_caracterizacion.csv"))

df_2 = pd.read_csv("udec_desercion_isc_caracterizacion.csv")
print("shape:", df_2.shape)     # (filas, columnas)
print("empty:", df_2.empty)     # False = tiene datos
print(df_2.dtypes.head(10))     # tipos de algunas columnas
# Out:
# cwd: D:\Proyecto_Desercion\notebooks
# existe archivo: True
# shape: (830, 33)
# empty: False
# DOCUMENTO                     int64
# GENERO                       object
# UBICACION_SEMESTRAL           int64
# MEDIO_TRANSPORTE             object
# FRECUENCIA_TRANSPORTE        object
# FUENTES_FINANCIACION         object
# PERSONAS_A_CARGO             object
# DIFICULTAD_PAGO_MATRICULA    object
# TURNO_TRABAJO_ESTUDIO        object
# TIPO_VIVIENDA_RESIDENCIA     object
# dtype: object

# %%
# Mostrar 20 primeras filas SIN truncar columnas
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)

df_2.head(20).to_string(index=False)
# Out:
# ' DOCUMENTO GENERO  UBICACION_SEMESTRAL    MEDIO_TRANSPORTE FRECUENCIA_TRANSPORTE FUENTES_FINANCIACION PERSONAS_A_CARGO DIFICULTAD_PAGO_MATRICULA TURNO_TRABAJO_ESTUDIO TIPO_VIVIENDA_RESIDENCIA ZONA_VIVIENDA_RESIDENCIA VIVE_PADRES_FAMILIAR SISBEN  NUM_HIJOS VIVE_PERSONAS_MAYORES VIVE_PERSONAS_PATOLOGIAS VICTIMA_VIOLENCIA FRECUENCIA_USO_CANALES_ATENCION ORIENTACION_CAT                COMUNA NIV_EDUCATIVO_PADRE_CAT NIV_EDUCATIVO_MADRE_CAT ES_VULNERABLE ES_GRUPO_ETNICO GRUPO_ETNICO_CAT HORAS_FUERA_CASA RECURSOS_TECNOLOGICOS HERMANOS_CAT CARGA_LABORAL     CARGA_HOGAR CONDICION_DISCAPACIDAD HABITOS_RIESGO   IMC_CAT\n1069737604      M                    2           Bicicleta                  Otro     Recursos propios       CON_CARGAS                        Si                 Mixto            Propia pagada              Zona urbana                   Si     No          2                    Si                       No                No             Con poca frecuencia    Heterosexual Comuna Sur 
# ...
